# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('Excel_Casev2_2020_Levy.xlsx')
df.head()
# Out:
#    Month  Year        Number  Entity  Dept  EOC  Unique Patient Account#  \
# 0      4  2017  220294000150     220  2940  150                     1000
# 1      1  2017  220294000150     220  2940  150                     1001
# 2      1  2017  220294000150     220  2940  150                     1002
# 3     12  2017  220294000150     220  2940  150                     1003
# 4      1  2017  220294000150     220  2940  150                     1004
#
#         AdmitDateTime   DischargeDateTime  Discharge Month  Length of Stay  \
# 0 2017-04-19 15:20:00 2017-04-24 13:05:00                4               5
# 1 2017-01-04 03:50:00 2017-01-09 13:15:00                1               5
# 2 2017-01-07 07:06:00 2017-01-09 17:33:00                1               2
# 3 2016-12-27 10:10:00 2017-01-02 11:30:00                1               6
# 4 2017-01-13 05:40:00 2017-01-15 15:30:00                1               2
#
#   Admit Nursing Station Discharge Nursing Station Discharge Disposition  \
# 0   WP LABOR & DELIVERY              WP 6F OB/GYN    HOME, SELF-CARE 01
# 1   WP LABOR & DELIVERY              WP 6F OB/GYN    HOME, SELF-CARE 01
# 2   WP LABOR & DELIVERY              WP 6F OB/GYN    HOME, SELF-CARE 01
# 3      WP 4I ORTHOPEDIC          WP 4I ORTHOPEDIC           XFER SNF 03
# 4   WP LABOR & DELIVERY              WP 6F OB/GYN    HOME, SELF-CARE 01
#
#     Charges    Billed  Insurance Payments  Patient Payments  Total Payments  \
# 0  29493.00  13721.80            13571.80               0.0        13571.80
# 1  26728.00  22336.38            22336.38               0.0        22336.38
# 2  12049.00   3817.35             3817.35               0.0         3817.35
# 3  25043.03   6073.59             6073.59               0.0         6073.59
# 4  12048.00   3954.62             3817.35               0.0         3817.35
#
#    Balance Product Line Financial Class Sub Category  AdmitAge
# 0   150.00   Obstetrics                        AETNA        31
# 1     0.00   Obstetrics                        CIGNA        34
# 2     0.00   Obstetrics                 MEDICAID HMO        21
# 3     0.00  Orthopedics                     MEDICARE        96
# 4   137.27   Obstetrics                 MEDICAID HMO        26
